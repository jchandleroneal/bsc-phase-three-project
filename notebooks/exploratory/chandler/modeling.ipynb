# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.impute import SimpleImputer
from sklearn.ensemble import BaggingClassifier
from sklearn.metrics import plot_confusion_matrix, auc, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from imblearn.over_sampling import SMOTE
from collections import Counter

df = pd.read_csv('../../../data/feature_engineering.csv')

# %%
df
# Out:
#        ref company_manufacturer company_location  review_date  \
# 0     2454                 5150           U.S.A.         2019
# 1     2458                 5150           U.S.A.         2019
# 2     2454                 5150           U.S.A.         2019
# 3      797             A. Morin           France         2012
# 4      797             A. Morin           France         2012
# ...    ...                  ...              ...          ...
# 2226  1205               Zotter          Austria         2014
# 2227  1996               Zotter          Austria         2017
# 2228  2170               Zotter          Austria         2018
# 2229  2170               Zotter          Austria         2018
# 2230  2036               Zotter          Austria         2018
#
#      country_of_bean_origin specific_bean_origin_or_bar_name  cocoa_percent  \
# 0                Madagascar           Bejofo Estate, batch 1           76.0
# 1        Dominican Republic                  Zorzal, batch 1           76.0
# 2                  Tanzania            Kokoa Kamili, batch 1           76.0
# 3                      Peru                             Peru           63.0
# 4                   Bolivia                          Bolivia           70.0
# ...                     ...                              ...            ...
# 2226                  Blend                              Raw           80.0
# 2227               Colombia                 APROCAFA, Acandi           75.0
# 2228                 Belize                         Maya Mtn           72.0
# 2229                  Congo            Mountains of the Moon           70.0
# 2230                  Blend  Dry Aged, 30 yr Anniversary bar           75.0
#
#        ingredients most_memorable_characteristics  rating  \
# 0         3- B,S,C   cocoa, blackberry, full body    3.75
# 1         3- B,S,C         cocoa, vegetal, savory    3.50
# 2         3- B,S,C      rich cocoa, fatty, bready    3.25
# 3       4- B,S,C,L          fruity, melon, roasty    3.75
# 4       4- B,S,C,L                 vegetal, nutty    3.50
# ...            ...                            ...     ...
# 2226  4- B,S*,C,Sa         waxy, cloying, vegetal    2.75
# 2227      3- B,S,C      strong nutty, marshmallow    3.75
# 2228      3- B,S,C      muted, roasty, accessible    3.50
# 2229      3- B,S,C   fatty, mild nuts, mild fruit    3.25
# 2230      3- B,S,C           fatty, earthy, cocoa    3.00
#
#             memorable_characteristics_list  company_loc_bins  \
# 0     ['cocoa', 'blackberry', 'full body']                 3
# 1           ['cocoa', 'vegetal', 'savory']                 3
# 2        ['rich cocoa', 'fatty', 'bready']                 3
# 3            ['fruity', 'melon', 'roasty']                 3
# 4                     ['vegetal', 'nutty']                 3
# ...                                    ...               ...
# 2226        ['waxy', 'cloying', 'vegetal']                 3
# 2227       ['strong nutty', 'marshmallow']                 3
# 2228     ['muted', 'roasty', 'accessible']                 3
# 2229  ['fatty', 'mild nuts', 'mild fruit']                 3
# 2230          ['fatty', 'earthy', 'cocoa']                 3
#
#       bean_origin_bins  weighted_specific_origin_bins ingredient_list  \
# 0                    3                              3           B,S,C
# 1                    3                              3           B,S,C
# 2                    3                              3           B,S,C
# 3                    3                              1         B,S,C,L
# 4                    3                              3         B,S,C,L
# ...                ...                            ...             ...
# 2226                 3                              3       B,S*,C,Sa
# 2227                 3                              3           B,S,C
# 2228                 3                              3           B,S,C
# 2229                 3                              3           B,S,C
# 2230                 3                              3           B,S,C
#
#      review_date_bin    cocoa_bucket  rating_class comp_manufact_bin
# 0                  b    (70.0, 99.0]             1                 b
# 1                  b    (70.0, 99.0]             1                 b
# 2                  b    (70.0, 99.0]             1                 b
# 3                  b  (45.999, 70.0]             1                 d
# 4                  b  (45.999, 70.0]             1                 d
# ...              ...             ...           ...               ...
# 2226               c    (70.0, 99.0]             0                 d
# 2227               a    (70.0, 99.0]             1                 d
# 2228               c    (70.0, 99.0]             1                 d
# 2229               c  (45.999, 70.0]             1                 d
# 2230               c    (70.0, 99.0]             1                 d
#
# [2231 rows x 19 columns]
